# %%
# string -> str 
#   i) character array (iterable -> for loop), len() ✔
#  ii) immutable data structure
# iii) binary representation / text representation ✔

# %%
full_name = "kate\t\n austen"

# %%
full_name = 'kate austen'

# %%
full_text = "kate's house"

# %%
print(full_name[0], full_name[1], full_name[2], "...")
# Out:
# k a t ...

# %%
full_name[::-1]
# Out:
# 'netsua \n\tetak'

# %%
try:
  full_name[-100]
except IndexError as err:
  print(err)
# Out:
# string index out of range

# %%
try:
  full_name[100]
except IndexError as err:
  print(err)
# Out:
# string index out of range

# %%
full_name[:4]
# Out:
# 'kate'

# %%
full_name[4:]
# Out:
# ' austen'

# %%
full_name[::2]
# Out:
# 'kt utn'

# %%
len(full_name)
# Out:
# 11

# %%
print(full_name)
# Out:
# kate
#  austen

# %%
for c in full_name: # character array -> loop
  if not c.isspace():
    print(c)
# Out:
# k
# a
# t
# e
# a
# u
# s
# t
# e
# n

# %%
json_circle = """{ 'x': 0,
  'y': 0,
  'radius': 1
}"""

# %%
json_circle
# Out:
# "{ 'x': 0,\n  'y': 0,\n  'radius': 1\n}"

# %%
json_circle.encode("utf-8")
# Out:
# b"{ 'x': 0,\n  'y': 0,\n  'radius': 1\n}"

# %%
currency = "₺"

# %%
len(currency)
# Out:
# 1

# %%
currency.encode("utf-8")
# Out:
# b'\xe2\x82\xba'

# %%
len(currency.encode("utf-8"))
# Out:
# 3

# %%
s = "x"

# %%
len(s)
# Out:
# 1

# %%
len(s.encode("utf-8"))
# Out:
# 1

# %%
clef = b"\xf0\x9d\x84\x9e"

# %%
len(clef)
# Out:
# 4

# %%
print(clef)
# Out:
# b'\xf0\x9d\x84\x9e'

# %%
clef = clef.decode("utf-8")

# %%
clef
# Out:
# '𝄞'

# %%
len(clef)
# Out:
# 1

# %%
len(clef.encode("utf-8"))
# Out:
# 4

# %%
# str's class methods:
#   i) isxyz -> True/False
#  ii) lower/upper/title/... : transformation
# iii) search methods: count/index/startsWith/endsWith -> int/True/False

# %%
name="jack"

# %%
name.upper()
# Out:
# 'JACK'

# %%
name
# Out:
# 'jack'

# %%
name[2] # you can read any character
# Out:
# 'c'

# %%
name[2]="M" # immutable -> you cannot change any character!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-7d3eb9aba3f9> in <module>()
# ----> 1 name[2]="M"
#
# TypeError: 'str' object does not support item assignment

# %%
name = "jack"

# %%
name = "kate" # "jack" is garbage now!

# %%
cities = ("izmir", "ankara", "antalya", "istanbul") # garbage ->

# %%
cities[2] = "eskisehir" # tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-8c6bef7c2e9f> in <module>()
# ----> 1 cities[2] = "eskisehir"
#
# TypeError: 'tuple' object does not support item assignment

# %%
cities = ("izmir", "ankara", "eskisehir", "istanbul")

# %%
# immutable data structure (str/tuple/...) -> memory consumption rises! -> functional programming

# %%
# str's class methods:
#   i) isxyz -> True/False
#  ii) lower/upper/title/... : transformation
# iii) search methods: count/index/startsWith/endsWith -> int/True/False

# %%
line = "      \n\t\t  \tjack shephard\t\t\t     \n\n\n\n"

# %%
print(line)
# Out:
#
# 		  	jack shephard

# %%
line.strip()
# Out:
# 'jack shephard'

# %%
line.lstrip()
# Out:
# 'jack shephard\t\t\t     \n\n\n\n'

# %%
line.rstrip()
# Out:
# '      \n\t\t  \tjack shephard'

# %%
line.strip(" \n\t")
# Out:
# 'jack shephard'

# %%
line="to be or not to be"

# %%
 replaced_line = line.replace("to","2")

# %%
line
# Out:
# 'to be or not to be'

# %%
replaced_line
# Out:
# '2 be or not 2 be'

# %%
line = "11111111110,           jack shephard, tr232342342535464576,        \t\t100000,\n1975"

# %%
print(line)
# Out:
# 11111111110,           jack shephard, tr232342342535464576,        		100000,
# 1975

# %%
line.split(",")
# Out:
# ['11111111110',
#  '           jack shephard',
#  ' tr232342342535464576',
#  '        \t\t100000',
#  '\n1975']

# %%
for column in line.split(","):
  print(column.strip())
# Out:
# 11111111110
# jack shephard
# tr232342342535464576
# 100000
# 1975
