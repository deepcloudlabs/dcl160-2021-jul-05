# %%
"""
  1. tuple        (4,8,15,16,23,42)  -> immutable like str  -> linear data structure
  2. list         [4,8,15,16,23,42]  -> mutable             -> linear data structure, allows duplicates
  3. set          {4,8,15,16,23,42}  -> mutable             -> linear data structure, unique
  4. dictionary   { "ankara": 312,   -> mutable             -> (key (set) -> value) associative data structure
                    "antalya": 242, 
                    "izmir": 342 }
"""
# Out:
# '\n  1. tuple        (4,8,15,16,23,42)  -> immutable like str  -> linear data structure\n  2. list         [4,8,15,16,23,42]  -> mutable             -> linear data structure, allows duplicates\n  3. set          {4,8,15,16,23,42}  -> mutable             -> linear data structure, unique\n  4. dictionary   { "ankara": 312,   -> mutable             -> (key (set) -> value) associative data structure\n                    "antalya": 242, \n                    "izmir": 342 }\n'

# %%
numbers = (4,8,15,16,23,42) # tuple

# %%
16 in numbers # linear search
# Out:
# True

# %%
108 in numbers
# Out:
# False

# %%
area_codes = { "ankara": 312, "antalya": 242,  "izmir": 342 , "antalya": 242 ,  "izmir": 345 }

# %%
area_codes
# Out:
# {'ankara': 312, 'antalya': 242, 'izmir': 345}

# %%
"antalya" in area_codes
# Out:
# True

# %%
"istanbul" in area_codes
# Out:
# False

# %%
area_codes["antalya"]
# Out:
# 242

# %%
s = set([1,2,3,1,2,3,1,2,3,1,2,3,1,2,3])

# %%
s
# Out:
# {1, 2, 3}

# %%
len(s)
# Out:
# 3

# %%
l = [1,2,3,1,2,3,1,2,3,1,2,3,1,2,3]

# %%
len(l)
# Out:
# 15

# %%
l
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# 1. tuple

# %%
numbers = [4,8,15,16,23,42] # list

# %%
numbers.append(108)

# %%
numbers
# Out:
# [4, 8, 15, 16, 23, 42, 108]

# %%
numbers.insert(3, 549)

# %%
numbers
# Out:
# [4, 8, 15, 549, 16, 23, 42, 108]

# %%
numbers = (4,8,15,16,23,42) # tuple: immutable data structure

# %%
sum(map( lambda u : u**2, filter(lambda n : n%2 != 0 , numbers )))
# Out:
# 754

# %%
numbers[0]
# Out:
# 4

# %%
len(numbers)
# Out:
# 6

# %%
print(numbers[1],numbers[2],numbers[3],numbers[4],numbers[5])
# Out:
# 8 15 16 23 42

# %%
numbers[-1]
# Out:
# 42

# %%
numbers[-2]
# Out:
# 23

# %%
numbers[-6]
# Out:
# 4

# %%
print(numbers[0], numbers[-len(numbers)])
# Out:
# 4 4

# %%
print(numbers[-1], numbers[len(numbers)-1])
# Out:
# 42 42

# %%
try:
  numbers[6]
except IndexError as err:
  print(err)
# Out:
# tuple index out of range

# %%
try:
  numbers[-7]
except IndexError as err:
  print(err)
# Out:
# tuple index out of range

# %%
for number in numbers:
  print(number)
# Out:
# 4
# 8
# 15
# 16
# 23
# 42

# %%
numbers = (4,8,15,16,23,42)
numbers[0:5:2]
# Out:
# (4, 15, 23)

# %%
sayilar = numbers[:] #cloning the data structure -> if it is tuple, you do not need to clone

# %%
sayilar = numbers[::-1] # reversing the elements in the data structure

# %%
sayilar
# Out:
# (42, 23, 16, 15, 8, 4)

# %%
numbers
# Out:
# (4, 8, 15, 16, 23, 42)

# %%
numbers = (1,2,3,1,2,3,1,2,3,1,2,3)
numbers.count(3)
# Out:
# 4

# %%
3 in numbers
# Out:
# True

# %%
numbers.count(3) > 0
# Out:
# True

# %%
numbers.index(3)
# Out:
# 2

# %%
numbers.index(3,3)
# Out:
# 5

# %%
numbers.index(3,6)
# Out:
# 8

# %%
numbers.index(3,9)
# Out:
# 11

# %%
try:
  numbers.index(108)
except ValueError as ve:
  print("Cannot find 108!")
# Out:
# Cannot find 108!

# %%
numbers = (1,2,3,1,2,3,1,2,3,1,2,3)
start = 0
while numbers.count(3) > 0:
  start = numbers.index(3,start,len(numbers))
  print(f"Found at {numbers.index(3,start)}")
  start += 1
  if start >= len(numbers):
    break
# Out:
# Found at 2
# Found at 5
# Found at 8
# Found at 11

# %%
3 in numbers
# Out:
# True

# %%
numbers.count(3) > 0
# Out:
# True

# %%
numbers = []

# %%
len(numbers)
# Out:
# 0

# %%
numbers.append(4)

# %%
numbers.append(8)

# %%
len(numbers)
# Out:
# 2

# %%
numbers
# Out:
# [4, 8]

# %%
numbers.insert(0,15)

# %%
numbers
# Out:
# [16, 15, 4, 8]

# %%
numbers.insert(0,16)

# %%
numbers.append(42)

# %%
numbers.append(23)

# %%
numbers
# Out:
# [16, 15, 4, 8, 42, 23]

# %%
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [42, 23, 16, 15, 8, 4]

# %%
names = ["ali","ayse", "sima", "zehra", "veli", "binnur"]

# %%
names.sort()

# %%
names
# Out:
# ['ali', 'ayse', 'binnur', 'sima', 'veli', 'zehra']

# %%
names.sort(reverse=True)

# %%
names
# Out:
# ['zehra', 'veli', 'sima', 'binnur', 'ayse', 'ali']

# %%
names.sort(key=lambda name: len(name) , reverse=True)

# %%
names
# Out:
# ['binnur', 'zehra', 'veli', 'sima', 'ayse', 'ali']

# %%
names.sort(key=len , reverse=True)

# %%
names
# Out:
# ['binnur', 'zehra', 'veli', 'sima', 'ayse', 'ali']

# %%
employees = [
    ("jack shephard", "Sales", 100000, 1978,True),
    ("kate austen", "IT", 200000, 1985,False),
    ("ben linus", "Finance", 150000, 1967,True),
    ("james sawyer", "HR", 70000, 1979,True),
    ("kim kwon", "Sales", 120000, 1986,True),
    ("sun kwon", "IT", 170000, 1984,False),
    ("hugo reyes", "IT", 120000, 1992,True)
]

# %%
# sort employees by salary in decending order
employees.sort(key= lambda employee : employee[2], reverse= True)

# %%
employees
# Out:
# [('kate austen', 'IT', 200000, 1985, False),
#  ('sun kwon', 'IT', 170000, 1984, False),
#  ('ben linus', 'Finance', 150000, 1967, True),
#  ('kim kwon', 'Sales', 120000, 1986, True),
#  ('hugo reyes', 'IT', 120000, 1992, True),
#  ('jack shephard', 'Sales', 100000, 1978, True),
#  ('james sawyer', 'HR', 70000, 1979, True)]

# %%
# sort employees by ages in decending order
employees.sort(key= lambda employee : employee[3], reverse= False)

# %%
employees
# Out:
# [('ben linus', 'Finance', 150000, 1967, True),
#  ('jack shephard', 'Sales', 100000, 1978, True),
#  ('james sawyer', 'HR', 70000, 1979, True),
#  ('sun kwon', 'IT', 170000, 1984, False),
#  ('kate austen', 'IT', 200000, 1985, False),
#  ('kim kwon', 'Sales', 120000, 1986, True),
#  ('hugo reyes', 'IT', 120000, 1992, True)]

# %%
def get_birth_year(employee):   # lambda employee : employee[3] ==> lambda expression -> anonymous function 
  return employee[3]

# %%
employees.sort(key= get_birth_year, reverse= False)

# %%
employees
# Out:
# [('ben linus', 'Finance', 150000, 1967, True),
#  ('jack shephard', 'Sales', 100000, 1978, True),
#  ('james sawyer', 'HR', 70000, 1979, True),
#  ('sun kwon', 'IT', 170000, 1984, False),
#  ('kate austen', 'IT', 200000, 1985, False),
#  ('kim kwon', 'Sales', 120000, 1986, True),
#  ('hugo reyes', 'IT', 120000, 1992, True)]

# %%
city_names = ("ankara", "istanbul", "izmir", "antalya", "eskisehir", "bursa")

# %%
sorted(city_names)
# Out:
# ['ankara', 'antalya', 'bursa', 'eskisehir', 'istanbul', 'izmir']

# %%
sorted(employees, key=get_birth_year)
# Out:
# [('ben linus', 'Finance', 150000, 1967, True),
#  ('jack shephard', 'Sales', 100000, 1978, True),
#  ('james sawyer', 'HR', 70000, 1979, True),
#  ('sun kwon', 'IT', 170000, 1984, False),
#  ('kate austen', 'IT', 200000, 1985, False),
#  ('kim kwon', 'Sales', 120000, 1986, True),
#  ('hugo reyes', 'IT', 120000, 1992, True)]

# %%
employees
# Out:
# [('ben linus', 'Finance', 150000, 1967, True),
#  ('jack shephard', 'Sales', 100000, 1978, True),
#  ('james sawyer', 'HR', 70000, 1979, True),
#  ('sun kwon', 'IT', 170000, 1984, False),
#  ('kate austen', 'IT', 200000, 1985, False),
#  ('kim kwon', 'Sales', 120000, 1986, True),
#  ('hugo reyes', 'IT', 120000, 1992, True)]

# %%
employees[0][0]
# Out:
# 'ben linus'

# %%
employees[0][1]
# Out:
# 'Finance'

# %%
employees[0][2]
# Out:
# 150000

# %%
employees[0][3]
# Out:
# 1967

# %%
employees[1]
# Out:
# ('jack shephard', 'Sales', 100000, 1978, True)

# %%
employees[:3]
# Out:
# [('ben linus', 'Finance', 150000, 1967, True),
#  ('jack shephard', 'Sales', 100000, 1978, True),
#  ('james sawyer', 'HR', 70000, 1979, True)]

# %%
employees[3:]
# Out:
# [('sun kwon', 'IT', 170000, 1984, False),
#  ('kate austen', 'IT', 200000, 1985, False),
#  ('kim kwon', 'Sales', 120000, 1986, True),
#  ('hugo reyes', 'IT', 120000, 1992, True)]

# %%
for employee in employees:
  if employee[-1]:
    print(employee[0])
# Out:
# ben linus
# jack shephard
# james sawyer
# kim kwon
# hugo reyes

# %%
employees[0]
# Out:
# ('ben linus', 'Finance', 150000, 1967, True)

# %%
full_name = employees[0][0]
department = employees[0][1]
salary = employees[0][2]
birth_year = employees[0][3]
full_time = employees[0][4]

# %%
full_name
# Out:
# 'ben linus'

# %%
department
# Out:
# 'Finance'

# %%
salary
# Out:
# 150000

# %%
full_name, department, salary, birth_year , full_time = employees[0] # unpacking -> tuple, list, set

# %%
print(full_name,department,salary,birth_year,full_time)
# Out:
# ben linus Finance 150000 1967 True

# %%
for full_name, department, salary, birth_year , full_time in employees: # unpacking with for-loop
  if full_time:
    print(full_name)
# Out:
# ben linus
# jack shephard
# james sawyer
# kim kwon
# hugo reyes

# %%
x = 3
y = 5

# %%
y , x = x , y

# %%
x
# Out:
# 5

# %%
y
# Out:
# 3

# %%
meyveler = ["elma", "armut", "kavun", "karpuz", "muz", "kiraz", "kivi"]

# %%
list(enumerate(meyveler))
# Out:
# [(0, 'elma'),
#  (1, 'armut'),
#  (2, 'kavun'),
#  (3, 'karpuz'),
#  (4, 'muz'),
#  (5, 'kiraz'),
#  (6, 'kivi')]

# %%
for idx,meyve in enumerate(meyveler):
  print(f"{idx} ==> {meyve}")
# Out:
# 0 ==> elma
# 1 ==> armut
# 2 ==> kavun
# 3 ==> karpuz
# 4 ==> muz
# 5 ==> kiraz
# 6 ==> kivi

# %%
for idx,meyve in enumerate(meyveler):
  print("%2d ==> %6s" % (idx,meyve))
# Out:
#  0 ==>   elma
#  1 ==>  armut
#  2 ==>  kavun
#  3 ==> karpuz
#  4 ==>    muz
#  5 ==>  kiraz
#  6 ==>   kivi

# %%
for idx,meyve in enumerate(meyveler):
  print("{index:>2x}\t==>\t{value:>6s}".format(value=meyve,index=idx))
# Out:
#  0	==>	  elma
#  1	==>	 armut
#  2	==>	 kavun
#  3	==>	karpuz
#  4	==>	   muz
#  5	==>	 kiraz
#  6	==>	  kivi

# %%
meyveler
# Out:
# ['elma', 'armut', 'kavun', 'karpuz', 'muz', 'kiraz', 'kivi']

# %%
meyveler.pop(4)
# Out:
# 'muz'

# %%
meyveler
# Out:
# ['elma', 'armut', 'kavun', 'karpuz', 'kiraz', 'kivi']

# %%
meyveler.pop(-1)
# Out:
# 'kiraz'

# %%
meyveler
# Out:
# ['elma', 'armut', 'kavun', 'karpuz']

# %%
try:
  meyveler.pop(8)
except IndexError as err:
  print(err)
# Out:
# pop index out of range

# %%
try:
  meyveler[8]
except IndexError as err:
  print(err)
# Out:
# list index out of range

# %%
meyveler.remove("kavun")

# %%
meyveler
# Out:
# ['elma', 'armut', 'karpuz']

# %%
try:
  meyveler.remove("kavun")
except ValueError as err:
  print(err)
# Out:
# list.remove(x): x not in list

# %%
"kavun" in meyveler
# Out:
# False

# %%
x = 42

# %%
x
# Out:
# 42

# %%
del x

# %%
meyveler
# Out:
# ['elma', 'armut', 'karpuz']

# %%
del meyveler[:]

# %%
meyveler
# Out:
# []

# %%
del meyveler

# %%
meyveler = ["elma", "armut", "kavun", "karpuz", "muz", "kiraz", "kivi"]

# %%
del meyveler[::2]

# %%
meyveler
# Out:
# ['armut', 'karpuz', 'kiraz']

# %%
orders = [
  ('msft', 100, 103.45, 'sell'),
  ('ibm',  200, 97.51, 'buy'),
  ('msft', 200, 102.12, 'sell'),
  ('ibm',  300, 98.15, 'buy'),
  ('msft', 500, 104.82, 'buy'),
  ('ibm',  150, 98.03, 'sell')
]

# %%
# order the list 'orders' by volume=price*quantity, descending

# %%
import random
lottery_numbers = []
while len(lottery_numbers) < 6:
  number = random.randint(1,60)
  if number not in lottery_numbers:
    lottery_numbers.append(number)
lottery_numbers.sort()
print(lottery_numbers)
# Out:
# [25, 36, 39, 48, 50, 58]

# %%
lottery_numbers = set([])
while len(lottery_numbers) < 6:
  lottery_numbers.update([random.randint(1,60)])
lottery_numbers = sorted(lottery_numbers)
print(lottery_numbers)
# Out:
# [10, 14, 25, 40, 53, 59]

# %%
{4, 8, 15}.issubset({15,8,42,4})
# Out:
# True

# %%
{4, 8, 42}.union({4,23,42})
# Out:
# {4, 8, 23, 42}

# %%
{4, 8, 42}.intersection({4,23,42})
# Out:
# {4, 42}

# %%
{4, 8, 42} | {4,23,42} # union
# Out:
# {4, 8, 23, 42}

# %%
{4, 8, 42} & {4,23,42} # intersection
# Out:
# {4, 42}

# %%
{4, 8, 15} < {15,8,42,4} # subset
# Out:
# True

# %%
{15,8,42,4} - {4, 8, 15} # {15,8,42,4}.difference({4, 8, 15})
# Out:
# {42}

# %%
area_codes = {
    "istanbul-anadolu": 216, # key : value
    "istanbul-avrupa": 212,
    "ankara": 312
}

# %%
area_codes["ankara"]
# Out:
# 312

# %%
"ankara" in area_codes
# Out:
# True

# %%
"izmir" in area_codes
# Out:
# False

# %%
area_codes.keys()
# Out:
# dict_keys(['istanbul-anadolu', 'istanbul-avrupa', 'ankara'])

# %%
area_codes.values()
# Out:
# dict_values([216, 212, 312])

# %%
area_codes.items()
# Out:
# dict_items([('istanbul-anadolu', 216), ('istanbul-avrupa', 212), ('ankara', 312)])

# %%
for city in area_codes.keys():
  print(f"{city}:\t{area_codes[city]}")
# Out:
# istanbul-anadolu:	216
# istanbul-avrupa:	212
# ankara:	312

# %%
for code in area_codes.values():
  print(code)
# Out:
# 216
# 212
# 312

# %%
for city,code in area_codes.items():
  print(f"{city}:\t{code}")
# Out:
# istanbul-anadolu:	216
# istanbul-avrupa:	212
# ankara:	312

# %%
area_codes.update({"bursa": 224})

# %%
area_codes.update({"antalya": 242})

# %%
for city,code in area_codes.items():
  print(f"{city}:\t{code}")
# Out:
# istanbul-anadolu:	216
# istanbul-avrupa:	212
# ankara:	312
# bursa:	224
# antalya:	242

# %%
area_codes.update({"izmir": 324})

# %%
for city,code in area_codes.items():
  print(f"{city}:\t{code}")
# Out:
# istanbul-anadolu:	216
# istanbul-avrupa:	212
# ankara:	312
# bursa:	1224
# antalya:	242
# izmir:	324

# %%
area_codes.update({"edirne": None})

# %%
print(area_codes["edirne"])
# Out:
# None

# %%
list(area_codes.keys())
# Out:
# ['istanbul-anadolu',
#  'istanbul-avrupa',
#  'ankara',
#  'bursa',
#  'antalya',
#  'izmir',
#  'edirne']

# %%
area_codes.pop("edirne")

# %%
list(area_codes.keys())
# Out:
# ['istanbul-anadolu', 'istanbul-avrupa', 'ankara', 'bursa', 'antalya', 'izmir']

# %%
del area_codes["bursa"]

# %%
list(area_codes.keys())
# Out:
# ['istanbul-anadolu', 'istanbul-avrupa', 'ankara', 'antalya', 'izmir']

# %%
try:
  area_codes.pop("bursa")
except KeyError as err:
  print("Cannot find 'bursa' in area codes!")
# Out:
# Cannot find 'bursa' in area codes!

# %%
try:
  area_codes["bursa"]
except KeyError as err:
  print("Cannot find 'bursa' in area codes!")
# Out:
# Cannot find 'bursa' in area codes!
